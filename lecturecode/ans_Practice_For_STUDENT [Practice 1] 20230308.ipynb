# %% [markdown]
# # Practice 1 0308

# %% [markdown]
# # Variable Reassignment & Function

# %% [markdown]
# ## Q0. Ice breaking : Your MBTI Best Match

# %% [markdown]
# **Guidelines**
# 1) Ask your group members' MBTI.<br>
# 2) Put '' around your type. ex) 'MBTI'<br>
# 3) See the chart below and make a function that will tell you your favorite mbti.

# %%
def myMBTImatch(mine:str) -> str:
  
    if mine == 'ISTJ':
        return 'ENTP', 'ENFP'
    elif mine == 'INTJ':
        return 'ENTP', 'ENFP'
    elif mine == 'ISFJ' :
        return 'ESFP', 'ESTP'
    elif mine == 'INFJ':
        return 'ENFP','ENTP','INTJ','INFJ' 
    elif mine == 'ISTP':
        return 'ESFJ', 'ESTJ'
    elif mine == 'ISFP':
        return 'ESFJ', 'ESTJ'
    elif mine == 'ISFP':
        return 'ESTJ', 'ESFJ'
    elif mine == 'INFP':
        return 'ENFJ', 'ENTJ'
    elif mine == 'INTP':
        return 'ENTJ', 'ENFJ'
    elif mine == 'ESTP':
        return 'ISTJ', 'ISFJ'
    elif mine == 'ESFP':
        return 'ISTJ', 'ISFJ'
    elif mine == 'ENFP':
        return 'INFJ', 'INTJ'
    elif mine == 'ENTP':
        return 'INTJ', 'INFJ'
    elif mine == 'ESTJ':
        return 'ISTP', 'ISFP'
    elif mine == 'ESFJ':
        return 'ISFP', 'ISTP'
    elif mine == 'ENFJ':
        return 'INFP', 'INTP'
    elif mine == 'ENTJ':
        return 'INTP', 'INFP'

# %% [markdown]
# https://www.ncchomelearning.co.uk/blog/myers-briggs-personality-types/

# %%
myMBTI = input()
# Out:
# ISFJ

# %%
myMBTImatch(myMBTI)
# Out:
# ('ESFP', 'ESTP')

# %% [markdown]
# # Practice 1.1

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-09-06%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.42.53.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-09-06%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.42.53.png)

# %%
f = min
f = max
g, h = min, max
# f = max, h = max
max = g # = min
k = max

# %%
h(1,5)
# Out:
# 5

# %%
g(h(1,5),3)
# Out:
# 3

# %%
f(2,g(h(1,5),3))
# Out:
# 3

# %%
max(f(2,g(h(1,5),3)),4)
# Out:
# 3

# %%
k(3,5)
# Out:
# 3

# %%
max(3,5)
# Out:
# 3

# %%
f(2,5)
# Out:
# 5

# %% [markdown]
# # Practice 1.2

# %% [markdown]
# ## Q1. exchange rate

# %% [markdown]
# ### Suppose that the exchange rate of won to dollar is 1.5. Create a function that changes won to the dollar.

# %% [markdown]
# **Guidelines**
# 1) dollar = exchange rate * won

# %% [markdown]
# ##### for students

# %%
def exchange(won:int)-> int:
    

    dollar = 1.5*won
 
    return int(dollar)

# %%
exchange(1500)
# Out:
# 2250

# %% [markdown]
# ## Q2. Switching position

# %% [markdown]
# ### Create a function in which the position of the number variable becomes that of characters.

# %% [markdown]
# **Guidelines**
# 1) Variable Reassignment

# %% [markdown]
# ##### for students

# %%
def swap_each(a: int, b: str)->None:
        
    #write your code here
    a, b = b, a

    return a, b

# %%
a = 1
b = 'a'

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
a, b = swap_each(a,b)

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# int

# %% [markdown]
# ## Q3. Area of Circle

# %% [markdown]
# ### Create a function of calculating the circle area.

# %% [markdown]
# **Guidelines**
# 1) The area of a circle is equal to Pi times the radius squared.

# %%
from numpy import pi

# %%
def circle_area(r:int):
    circle_area = pi*r**2
    return circle_area

# %%
circle_area(10)
# Out:
# 314.1592653589793

# %% [markdown]
# ## Q4. Variable Reassignment with Function

# %% [markdown]
# ### Create a function by following directions

# %% [markdown]
# **Directions**
# 1) First, define the middle and large functions last.  \
# 2) Remind what variable Reassignment is.  \
# 2) Test with calling large function.

# %% [markdown]
# ##### large function answer

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-09-06%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.14.22.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-09-06%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.14.22.png)

# %% [markdown]
# ##### for students

# %%
def small_func() -> None:
    print('small_func')
    return

# %%
def middle_func() -> None:
    small_func()
    print('middle_func')
    return

# %%
def large_func() -> None:
    middle_func()
    print('large_func')
    return

# %%
large_func()
# Out:
# small_func
# middle_func
# large_func
